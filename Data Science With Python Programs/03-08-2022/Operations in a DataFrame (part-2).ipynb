# %%
import pandas as pd
df=pd.read_csv("100 Sales Records.csv")

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df1=df[["Country","Item Type","Sales Channel","Units Sold"]]

# %%
df1
# Out:
#                   Country        Item Type Sales Channel  Units Sold
# 0                  Tuvalu        Baby Food       Offline        9925
# 1                 Grenada           Cereal        Online        2804
# 2                  Russia  Office Supplies       Offline        1779
# 3   Sao Tome and Principe           Fruits        Online        8102
# 4                  Rwanda  Office Supplies       Offline        5062
# ..                    ...              ...           ...         ...
# 95                   Mali          Clothes        Online         888
# 96               Malaysia           Fruits       Offline        6267
# 97           Sierra Leone       Vegetables       Offline        1485
# 98                 Mexico    Personal Care       Offline        5767
# 99             Mozambique        Household       Offline        5367
#
# [100 rows x 4 columns]

# %%
#Condtional Operations in DataFrame..
df1[df1["Sales Channel"]=="Offline"].count()
# Out:
# Country          50
# Item Type        50
# Sales Channel    50
# Units Sold       50
# dtype: int64

# %%
print(df1)
df1=df1[df1["Units Sold"]<1000]
df2=df1["Units Sold"]
df2
# Out:
#                   Country        Item Type Sales Channel  Units Sold
# 0                  Tuvalu        Baby Food       Offline        9925
# 1                 Grenada           Cereal        Online        2804
# 2                  Russia  Office Supplies       Offline        1779
# 3   Sao Tome and Principe           Fruits        Online        8102
# 4                  Rwanda  Office Supplies       Offline        5062
# ..                    ...              ...           ...         ...
# 95                   Mali          Clothes        Online         888
# 96               Malaysia           Fruits       Offline        6267
# 97           Sierra Leone       Vegetables       Offline        1485
# 98                 Mexico    Personal Care       Offline        5767
# 99             Mozambique        Household       Offline        5367
#
# [100 rows x 4 columns]
# 10    124
# 43    171
# 45    962
# 47    273
# 58    282
# 60    682
# 71    673
# 88    522
# 90    948
# 95    888
# ...

# %%
df1[(df1["Units Sold"]<1000) & (df1["Sales Channel"]=="Offline")]
# Out:
#          Country        Item Type Sales Channel  Units Sold
# 45       Comoros           Cereal       Offline         962
# 60     Australia           Cereal       Offline         682
# 90  Sierra Leone  Office Supplies       Offline         948

# %%
df3=df1[(df1["Units Sold"]<1000) | (df1["Sales Channel"]=="Offline")]
df3
# Out:
#            Country        Item Type Sales Channel  Units Sold
# 10      Kyrgyzstan       Vegetables        Online         124
# 43        Slovakia       Vegetables        Online         171
# 45         Comoros           Cereal       Offline         962
# 47     Switzerland    Personal Care        Online         273
# 58  United Kingdom        Household        Online         282
# 60       Australia           Cereal       Offline         682
# 71           Libya           Fruits        Online         673
# 88          Kuwait           Fruits        Online         522
# 90    Sierra Leone  Office Supplies       Offline         948
# 95            Mali          Clothes        Online         888

# %%
#Loc operation to identify particular element in a specific row and a specific coloumn
df4=df3.loc[df3["Units Sold"]<500,"Country"]
df4
# Out:
# 10        Kyrgyzstan
# 43          Slovakia
# 47       Switzerland
# 58    United Kingdom
# Name: Country, dtype: object

# %%
df3.iloc[2:5,2:5]
# Out:
#    Sales Channel  Units Sold
# 45       Offline         962
# 47        Online         273
# 58        Online         282

# %%
filex=df.to_excel("100 Sales Records.xlsx",sheet_name="Sales Records")

# %%
dF=pd.read_excel("100 Sales Records.xlsx")

# %%
dF
# Out:
#     Unnamed: 0                             Region                Country  \
# 0            0              Australia and Oceania                 Tuvalu
# 1            1  Central America and the Caribbean                Grenada
# 2            2                             Europe                 Russia
# 3            3                 Sub-Saharan Africa  Sao Tome and Principe
# 4            4                 Sub-Saharan Africa                 Rwanda
# ..         ...                                ...                    ...
# 95          95                 Sub-Saharan Africa                   Mali
# 96          96                               Asia               Malaysia
# 97          97                 Sub-Saharan Africa           Sierra Leone
# 98          98                      North America                 Mexico
# 99          99                 Sub-Saharan Africa             Mozambique
#
#           Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

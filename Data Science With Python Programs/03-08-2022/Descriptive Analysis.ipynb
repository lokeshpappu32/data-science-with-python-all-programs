# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("IPL IMB381IPL2013.csv")

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %%
#Display top elements of a dataset
df.head(10)
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1    Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2   Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3    Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# ...

# %%
df.tail(5)#To display last 5 elements of a dataset
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.head(10).tail(2)#To display 9th and 10th rows of a table
# Out:
#    Sl.NO.  PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 8       9     Botha, J    2      SA    RR   Allrounder      83      17
# 9      10  Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 8         609     85.77  ...  114.73       3     610    19   32.11  6.85
# 9        4686     84.76  ...  127.51      13       0     0    0.00  0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 8  28.11          2011      200000      950000
# 9   0.00          2008      200000      450000
#
# [2 rows x 26 columns]

# %%
list(df.columns)##To display the coloumn names of the given dataset
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.head(10).tail(4).transpose()#To display the rows as coloumns and coloumns as rows
# Out:
#                        6              7           8            9
# Sl.NO.                 7              8           9           10
# PLAYER NAME    Balaji, L  Bollinger, DE    Botha, J  Boucher, MV
# AGE                    2              2           2            2
# COUNTRY              IND            AUS          SA           SA
# TEAM                CSK+            CSK          RR         RCB+
# PLAYING ROLE      Bowler         Bowler  Allrounder    W. Keeper
# T-RUNS                51             54          83         5515
# T-WKTS                27             50          17            1
# ODI-RUNS-S           120             50         609         4686
# ODI-SR-B           78.94          92.59       85.77        84.76
# ODI-WKTS              34             62          72            0
# ODI-SR-BL           42.5           31.3        53.0          0.0
# CAPTAINCY EXP          0              0           1            1
# ...

# %%
df.shape  #To display number of rows and coloumns in a dataset
# Out:
# (130, 26)

# %%
#Slicing Rows and coloumns in a dataset
df[3:10]#Display the elements from index 3 upto 10
# Out:
#    Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 3       4      Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5   Badrinath, S    2     IND   CSK      Batsman      63       0
# 5       6     Bailey, GJ    2     AUS   CSK      Batsman       0       0
# 6       7      Balaji, L    2     IND  CSK+       Bowler      51      27
# 7       8  Bollinger, DE    2     AUS   CSK       Bowler      54      50
# 8       9       Botha, J    2      SA    RR   Allrounder      83      17
# 9      10    Boucher, MV    2      SA  RCB+    W. Keeper    5515       1
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 3         241     84.56  ...   76.32       0    1125    49   22.96  6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00  0.00
# 5         172     72.26  ...   95.45       0       0     0    0.00  0.00
# 6         120     78.94  ...   72.22       1    1342    52   25.81  7.98
# ...

# %%
df[['PLAYER NAME','TEAM']][3:6]
# Out:
#     PLAYER NAME TEAM
# 3     Ashwin, R  CSK
# 4  Badrinath, S  CSK
# 5    Bailey, GJ  CSK

# %%
df.iloc[1:3,9:13]#[x,y] x indicate no.of rows to be displayed and y indicate number of coloumns to be displayed
# Out:
#    ODI-SR-B  ODI-WKTS  ODI-SR-BL  CAPTAINCY EXP
# 1     71.41       185       37.6              0
# 2     80.62       288       32.9              0

# %%
df["PLAYING ROLE"].value_counts()
# Out:
# Bowler        44
# Batsman       39
# Allrounder    35
# W. Keeper     12
# Name: PLAYING ROLE, dtype: int64

# %%
df["PLAYING ROLE"].value_counts(normalize=True)*100#Percentage of each specific value
# Out:
# Bowler        33.846154
# Batsman       30.000000
# Allrounder    26.923077
# W. Keeper      9.230769
# Name: PLAYING ROLE, dtype: float64

# %%
pd.crosstab(df["PLAYING ROLE"],df["TEAM"])
# Out:
# TEAM          CSK  CSK+  DC  DC+  DD  DD+  KKR  KKR+  KXI+  KXIP  KXIP+  MI  \
# PLAYING ROLE
# Allrounder      3     1   1    3   2    3    0     4     0     3      1   2
# Batsman         6     0   3    3   2    2    1     2     0     2      3   1
# Bowler          4     3   3    3   2    3    3     4     1     0      2   3
# W. Keeper       1     1   0    1   0    2    1     2     0     0      1   0
#
# TEAM          MI+  RCB  RCB+  RR  RR+
# PLAYING ROLE
# Allrounder      2    3     2   2    3
# Batsman         3    3     5   1    2
# Bowler          1    3     4   2    3
# W. Keeper       0    0     1   1    1

# %%
df[["PLAYER NAME","AGE","COUNTRY","TEAM","RUNS-S"]].sort_values("RUNS-S")[0:10]
#Sorting entire dataset based on one paricular coloumn of the data set
# Out:
#        PLAYER NAME  AGE COUNTRY  TEAM  RUNS-S
# 0      Abdulla, YA    2      SA  KXIP       0
# 1     Abdur Razzak    2     BAN   RCB       0
# 98   Shoaib Akhtar    3     PAK   KKR       2
# 126    Younis Khan    2     PAK    RR       3
# 114       Tyagi, S    1     IND   CSK       3
# 46     Kamran Khan    1     IND   RR+       3
# 66   Mohammad Asif    2     PAK    DD       3
# 21   Fernando, CRD    2      SL    MI       4
# 62     McGrath, GD    3     AUS    DD       4
# 20     Edwards, FH    2      WI    DC       4

# %%
df[["PLAYER NAME","AGE","COUNTRY","TEAM","RUNS-S"]].sort_values("RUNS-S",ascending=False)[0:10]
#Sorting entire dataset based on one paricular coloumn of the data set in a descending order
# Out:
#        PLAYER NAME  AGE COUNTRY  TEAM  RUNS-S
# 88       Raina, SK    1     IND   CSK    2254
# 24      Gambhir, G    2     IND   DD+    2065
# 111  Tendulkar, SR    3     IND    MI    2047
# 97      Sharma, RG    1     IND   DC+    1975
# 44      Kallis, JH    3      SA   RCB    1965
# 93       Sehwag, V    2     IND    DD    1879
# 26       Gayle, CH    2      WI  KKR+    1804
# 15       Dhoni, MS    2     IND   CSK    1782
# 28   Gilchrist, AC    3     AUS   DC+    1775
# 18      Dravid, RS    3     IND  RCB+    1703

# %%
df.groupby("COUNTRY")[["RUNS-S","PLAYER NAME"]].max()
# Out:
#          RUNS-S      PLAYER NAME
# COUNTRY
# AUS        1775        White, CL
# BAN           0     Abdur Razzak
# ENG         634    Pietersen, KP
# IND        2254      Zaheer Khan
# NZ         1233      Vettori, DL
# PAK         128      Younis Khan
# SA         1965  de Villiers, AB
# SL         1567       Zoysa, DNT
# WI         1804        Smith, DR
# ZIM          31         Taibu, T

# %%
x=df.groupby("AGE")["SOLD PRICE"].mean().reset_index()

# %%
x
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
df.groupby(["AGE","PLAYING ROLE"])["SOLD PRICE"].mean().reset_index()
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %%
#Renaming the coloumn value
df.rename(columns={"SOLD PRICE":"SOLD VALUE"},inplace=True)
df[["PLAYER NAME","SOLD VALUE"]].head(2)
# Out:
#     PLAYER NAME  SOLD VALUE
# 0   Abdulla, YA       50000
# 1  Abdur Razzak       50000

# %%
df[df["SIXERS"]>80][["PLAYER NAME","AGE","SIXERS"]]
# Out:
#       PLAYER NAME  AGE  SIXERS
# 26      Gayle, CH    2     129
# 28  Gilchrist, AC    3      86
# 82     Pathan, YK    2      81
# 88      Raina, SK    1      97
# 97     Sharma, RG    1      82

# %%
#Removing a coloumn from a dataset
df["BASE PRICE"]
df.drop("BASE PRICE",inplace=True,axis=1)

# %%
#Dealing with Missing values in a dataset
